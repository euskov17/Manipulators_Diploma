# %%
from Manipulator2DMap.Map import GridMap2D
from Manipulator2DMap.Manipulator2D import Manipulator_2d_supervisor, PI
from Manipulator2DMap.obstacle import SphereObstacle
from AStarDefaults.AStar import AStar, make_path

import numpy as np
import matplotlib.pyplot as plt
import itertools
import time
import heapq
from matplotlib.widgets import Slider
from ipywidgets import interact

# %matplotlib inline

# %%
N_JOINTS = 4

args_dict = {
    'num_joints': N_JOINTS,
    'lengths': [5, 7, 5, 5],
    'angle_discretization': 180,
    'angles_constraints': np.array([PI / 6] * N_JOINTS)
}

# %%
manipulator = Manipulator_2d_supervisor(**args_dict)

state = manipulator.generate_random_state()
state
# Out:
# array([ 2.0943951 , -1.43116999, -0.52359878, -0.90757121])

# %%
goal_position = ((-10, 5.5), -PI/ 2)

manipulator = Manipulator_2d_supervisor(**args_dict)

# %%
sphere_obstacle = SphereObstacle(np.array([-5, 5]), 3)

# %%
space_map = GridMap2D(manipulator, state, goal_position, obstacles=[sphere_obstacle])
# Out:
# print goal position [-10.    5.5]

# %%
if space_map.get_start() is None:
    space_map.random_init_start()
manipulator.visualize_state(space_map.get_start())

# %%
# %time result, last_state, steps, nodes_created, OPEN, CLOSED = AStar(space_map)
# Out:
# step = 50000 g = 4.468042885105486 heuristic = 10.991123060891152 dist = 10.991123060891152
# step = 100000 g = 4.363323129985826 heuristic = 11.651223556641483 dist = 11.651223556641483
# step = 150000 g = 4.53785605518526 heuristic = 11.849951482845503 dist = 11.849951482845503
# step = 200000 g = 3.8048177693476406 heuristic = 12.862459859637557 dist = 12.862459859637557
# step = 250000 g = 0.45378560551852565 heuristic = 16.43256490985601 dist = 16.43256490985601
# step = 300000 g = 4.258603374866167 heuristic = 12.795623272229417 dist = 12.795623272229417
# step = 350000 g = 4.64257581030492 heuristic = 12.407802850295733 dist = 12.407802850295733
# step = 400000 g = 5.340707511102647 heuristic = 11.984950247625573 dist = 11.984950247625573
# step = 450000 g = 3.7699111843077535 heuristic = 13.690810648037846 dist = 13.690810648037846
# step = 500000 g = 7.33038285837619 heuristic = 10.25992490160311 dist = 10.25992490160311
# step = 550000 g = 4.642575810304919 heuristic = 13.071264475984442 dist = 13.071264475984442
# step = 600000 g = 8.552113334772221 heuristic = 9.278299288141222 dist = 9.278299288141222
# step = 650000 g = 7.609635538695279 heuristic = 10.333371634178683 dist = 10.333371634178683
# step = 700000 g = 7.888888219014374 heuristic = 10.161644415336752 dist = 10.161644415336752
# step = 750000 g = 9.389871375729497 heuristic = 8.765083595788381 dist = 8.765083595788381
# step = 800000 g = 5.829399701661065 heuristic = 12.4242904121553 dist = 12.4242904121553
# step = 850000 g = 6.876597252857658 heuristic = 11.461128082163626 dist = 11.461128082163626
# step = 900000 g = 4.852015320544238 heuristic = 13.573943331802734 dist = 13.573943331802734
# step = 950000 g = 8.447393579652559 heuristic = 10.06289438155188 dist = 10.06289438155188
# step = 1000000 g = 3.4557519189487746 heuristic = 15.136304405699503 dist = 15.136304405699503
# Stop by max_steps
# OPEN is empty
# CPU times: user 21min 36s, sys: 1.55 s, total: 21min 38s
# Wall time: 21min 38s

# %%
path, length = make_path(last_state)

# %%
a = np.array([space_map._manipulator.calculate_end(st.state) for st in CLOSED])

# %%
plt.scatter(a[:, 0], a[:,1])
plt.scatter(goal_position[0][0], goal_position[0][1])

# %%
def visualize_path_state(path_state=0):
    space_map._manipulator.visualize_state(path[path_state])
    c = plt.Circle(space_map._obstacles[0].center, space_map._obstacles[0].r)
    plt.gca().add_artist(c)

np.set_printoptions(precision=5)
interact(visualize_path_state, path_state=(0, len(path) - 1))
plt.show()
# Out:
# interactive(children=(IntSlider(value=0, description='path_state', max=91), Output()), _dom_classes=('widget-i…
